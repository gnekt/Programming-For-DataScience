# %% [markdown]
# * Read data from the CSV file state-population.csv, state-areas.csv, and state-abbrevs.csv and same them as pd.DataFrames

# %%
import pandas as pd

# %%
state_population = pd.read_csv("state-population.csv")
print(state_population)
state_areas = pd.read_csv("state-areas.csv")
print(state_areas)
state_abbrevs = pd.read_csv("state-abbrevs.csv")
print(state_abbrevs)
# Out:
#      state/region     ages  year   population
# 0              AL  under18  2012    1117489.0
# 1              AL    total  2012    4817528.0
# 2              AL  under18  2010    1130966.0
# 3              AL    total  2010    4785570.0
# 4              AL  under18  2011    1125763.0
# ...           ...      ...   ...          ...
# 2539          USA    total  2010  309326295.0
# 2540          USA  under18  2011   73902222.0
# 2541          USA    total  2011  311582564.0
# 2542          USA  under18  2012   73708179.0
# 2543          USA    total  2012  313873685.0
#
# [2544 rows x 4 columns]
#                    state  area (sq. mi)
# 0                Alabama          52423
# 1                 Alaska         656425
# 2                Arizona         114006
# 3               Arkansas          53182
# 4             California         163707
# 5               Colorado         104100
# 6            Connecticut           5544
# 7               Delaware           1954
# ...

# %% [markdown]
# * Use the head method to take a look at the three dataframes

# %%
print(state_abbrevs.head())
print(state_areas.head())
print(state_population.head())
# Out:
#         state abbreviation
# 0     Alabama           AL
# 1      Alaska           AK
# 2     Arizona           AZ
# 3    Arkansas           AR
# 4  California           CA
#         state  area (sq. mi)
# 0     Alabama          52423
# 1      Alaska         656425
# 2     Arizona         114006
# 3    Arkansas          53182
# 4  California         163707
#   state/region     ages  year  population
# 0           AL  under18  2012   1117489.0
# 1           AL    total  2012   4817528.0
# 2           AL  under18  2010   1130966.0
# 3           AL    total  2010   4785570.0
# 4           AL  under18  2011   1125763.0

# %% [markdown]
# # AIM: rank states in the USA by population density
# * Merge population data with abbreviation data

# %%
print(pd.merge(state_population,state_abbrevs,left_on="state/region",right_on="abbreviation"))
# Out:
#      state/region     ages  year  population    state abbreviation
# 0              AL  under18  2012   1117489.0  Alabama           AL
# 1              AL    total  2012   4817528.0  Alabama           AL
# 2              AL  under18  2010   1130966.0  Alabama           AL
# 3              AL    total  2010   4785570.0  Alabama           AL
# 4              AL  under18  2011   1125763.0  Alabama           AL
# ...           ...      ...   ...         ...      ...          ...
# 2443           WY  under18  1993    137458.0  Wyoming           WY
# 2444           WY    total  1991    459260.0  Wyoming           WY
# 2445           WY  under18  1991    136720.0  Wyoming           WY
# 2446           WY  under18  1990    136078.0  Wyoming           WY
# 2447           WY    total  1990    453690.0  Wyoming           WY
#
# [2448 rows x 6 columns]

# %% [markdown]
# * What is the size of the dataframe resulting from the merging ? Is it the same of the original population dataframe ?

# %% [markdown]
# * Repeat the merge so that no rows are missed from the original dataframes

# %%
merge_1 = pd.merge(state_population,state_abbrevs,left_on="state/region",right_on="abbreviation",how="outer")
print(merge_1)
# Out:
#      state/region     ages  year   population    state abbreviation
# 0              AL  under18  2012    1117489.0  Alabama           AL
# 1              AL    total  2012    4817528.0  Alabama           AL
# 2              AL  under18  2010    1130966.0  Alabama           AL
# 3              AL    total  2010    4785570.0  Alabama           AL
# 4              AL  under18  2011    1125763.0  Alabama           AL
# ...           ...      ...   ...          ...      ...          ...
# 2539          USA    total  2010  309326295.0      NaN          NaN
# 2540          USA  under18  2011   73902222.0      NaN          NaN
# 2541          USA    total  2011  311582564.0      NaN          NaN
# 2542          USA  under18  2012   73708179.0      NaN          NaN
# 2543          USA    total  2012  313873685.0      NaN          NaN
#
# [2544 rows x 6 columns]

# %% [markdown]
# * Which columns include null values ? [use methods isnull and any]

# %%
merge_1.isna().any()
# Out:
# state/region    False
# ages            False
# year            False
# population       True
# state            True
# abbreviation     True
# dtype: bool

# %% [markdown]
# * Get the rows where state or abbreviation contains null values

# %%
merge_1.isna().any(axis="columns")
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2539     True
# 2540     True
# 2541     True
# 2542     True
# 2543     True
# Length: 2544, dtype: bool

# %% [markdown]
# * Find the values of the state/region column for the rows with null values [method unique]

# %%
print(state_population.index[merge_1.isna().any(axis="columns") == True])
idx = merge_1
# Out:
# Int64Index([2448, 2449, 2450, 2451, 2452, 2453, 2454, 2455, 2456, 2457, 2458,
#             2459, 2460, 2461, 2462, 2463, 2464, 2465, 2466, 2467, 2468, 2469,
#             2470, 2471, 2472, 2473, 2474, 2475, 2476, 2477, 2478, 2479, 2480,
#             2481, 2482, 2483, 2484, 2485, 2486, 2487, 2488, 2489, 2490, 2491,
#             2492, 2493, 2494, 2495, 2496, 2497, 2498, 2499, 2500, 2501, 2502,
#             2503, 2504, 2505, 2506, 2507, 2508, 2509, 2510, 2511, 2512, 2513,
#             2514, 2515, 2516, 2517, 2518, 2519, 2520, 2521, 2522, 2523, 2524,
#             2525, 2526, 2527, 2528, 2529, 2530, 2531, 2532, 2533, 2534, 2535,
#             2536, 2537, 2538, 2539, 2540, 2541, 2542, 2543],
#            dtype='int64')

# %% [markdown]
# * Fix the abbreviations dataframe so that no null values are obtained for the columns state and abbreviation when performing the merging
# * Note: PR = Puerto Rico; USA = United States
# * Check that there are no null values left in the columns state and abbreviation

# %%
state_abbrevs = state_abbrevs.append(pd.DataFrame([["United States",'USA'],["Puerto Rico","PR"]], columns=["state","abbreviation"]), ignore_index=True)
merge_1 = pd.merge(merge_1,state_abbrevs,right_on="abbreviation",left_on="state/region",how="outer")
print(merge_1)
merge_1.isna().any()
# Out:
#      state/region     ages    year   population  state_x abbreviation  \
# 0              AL  under18  2012.0    1117489.0  Alabama           AL
# 1              AL    total  2012.0    4817528.0  Alabama           AL
# 2              AL  under18  2010.0    1130966.0  Alabama           AL
# 3              AL    total  2010.0    4785570.0  Alabama           AL
# 4              AL  under18  2011.0    1125763.0  Alabama           AL
# ...           ...      ...     ...          ...      ...          ...
# 2541          USA    total  2011.0  311582564.0      NaN          NaN
# 2542          USA  under18  2012.0   73708179.0      NaN          NaN
# 2543          USA    total  2012.0  313873685.0      NaN          NaN
# 2544          NaN      NaN     NaN          NaN      NaN          USA
# 2545          NaN      NaN     NaN          NaN      NaN           PR
#
#             state_y
# 0           Alabama
# 1           Alabama
# 2           Alabama
# 3           Alabama
# ...

# %% [markdown]
# * Now merge with the area dataframe

# %%
print(merge_1.head())
print(state_areas.head())
merge_2 = pd.merge(merge_1, state_areas, on="state")
print(merge_2.head())
# Out:
#   state/region     ages    year  population  state_x abbreviation  state_y
# 0           AL  under18  2012.0   1117489.0  Alabama           AL  Alabama
# 1           AL    total  2012.0   4817528.0  Alabama           AL  Alabama
# 2           AL  under18  2010.0   1130966.0  Alabama           AL  Alabama
# 3           AL    total  2010.0   4785570.0  Alabama           AL  Alabama
# 4           AL  under18  2011.0   1125763.0  Alabama           AL  Alabama
#         state  area (sq. mi)
# 0     Alabama          52423
# 1      Alaska         656425
# 2     Arizona         114006
# 3    Arkansas          53182
# 4  California         163707
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_540/198503934.py in <module>
#       1 print(merge_1.head())
#       2 print(state_areas.head())
# ----> 3 merge_2 = pd.merge(merge_1, state_areas, on="state")
# ...

# %% [markdown]
# * Which states have null values for the area ?
# * Which states have null values for the population ?

# %%
merge_2[merge_2['population'].isna() == True]
merge_2[merge_2['area (sq. mi)'].isna() == True]
# Out:
# Empty DataFrame
# Columns: [state/region, ages, year, population, state, abbreviation, area (sq. mi)]
# Index: []

# %% [markdown]
# * Remove all null values from the dataframe

# %% [markdown]
# * Select the rows corresponding to the total population in the year 2010

# %% [markdown]
# * Add to the dataframe a column with the density values

# %% [markdown]
# * Sort the dataframe by ascending density
